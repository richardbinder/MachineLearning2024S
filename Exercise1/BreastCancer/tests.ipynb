# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

from sklearn.tree import DecisionTreeClassifier

from sklearn.neighbors import KNeighborsClassifier

dataset = pd.read_csv('./dataset/breast-cancer-diagnostic.shuf.lrn.csv')
test_data = pd.read_csv('./dataset/breast-cancer-diagnostic.shuf.tes.csv')
test_data_class = pd.read_csv('./dataset/breast-cancer-diagnostic.shuf.sol.ex.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier

X = dataset.drop('class', axis=1)
y = dataset['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.9651162790697675

# %%
dataset = dataset.drop('ID', axis=1)
test_data = test_data.drop('ID', axis=1)

dataset['class'] = dataset['class'].astype(int)
test_data_class['class'] = test_data_class['class'].astype(int)

scaler = StandardScaler()
columns_to_scale = dataset.columns.difference(['class'])
dataset[columns_to_scale] = scaler.fit_transform(dataset[columns_to_scale])
test_data[columns_to_scale] = scaler.transform(test_data[columns_to_scale])

X_attributes = dataset.drop('class', axis=1)
Y_class = dataset['class']

X_attributes_test = test_data
Y_class_test = test_data_class['class']

# %%
# Train a Random Forest model to get which features are more important
model = RandomForestClassifier()
model.fit(X_attributes, Y_class)

most_important_attributes = pd.DataFrame(
                            model.feature_importances_,
                            index = X_attributes.columns,
                            columns=['importance']
                        ).sort_values('importance', ascending=False)

print(most_important_attributes)


## Get a list of the most important features
most_important_attributes_list = most_important_attributes[most_important_attributes['importance'] > 0].index.tolist()
print(most_important_attributes_list)
# Out:
#                          importance
#  concavePointsWorst        0.198596
#  concavePointsMean         0.167450
#  areaWorst                 0.075711
#  perimeterWorst            0.072916
#  radiusWorst               0.067241
#  areaMean                  0.064468
#  concavityWorst            0.051421
#  concavityMean             0.049221
# radiusMean                 0.032910
#  areaStdErr                0.032446
#  perimeterMean             0.027070
#  compactnessWorst          0.025947
#  smoothnessWorst           0.016672
#  textureMean               0.013634
#  compactnessMean           0.012823
#  textureWorst              0.011693
#  symmetryWorst             0.009954
#  radiusStdErr              0.008589
#  perimeterStdErr           0.008356
#  concavePointsStdErr       0.007235
#  concavityStdErr           0.006647
#  fractalDimensionWorst     0.006082
#  smoothnessMean            0.005976
#  symmetryMean              0.004666
#  fractalDimensionMean      0.004424
#  textureStdErr             0.004134
#  smoothnessStdErr          0.004098
#  fractalDimensionStdErr    0.003980
#  symmetryStdErr            0.002822
#  compactnessStdErr         0.002816
# [' concavePointsWorst', ' concavePointsMean', ' areaWorst', ' perimeterWorst', ' radiusWorst', ' areaMean', ' concavityWorst', ' concavityMean', 'radiusMean', ' areaStdErr', ' perimeterMean', ' compactnessWorst', ' smoothnessWorst', ' textureMean', ' compactnessMean', ' textureWorst', ' symmetryWorst', ' radiusStdErr', ' perimeterStdErr', ' concavePointsStdErr', ' concavityStdErr', ' fractalDimensionWorst', ' smoothnessMean', ' symmetryMean', ' fractalDimensionMean', ' textureStdErr', ' smoothnessStdErr', ' fractalDimensionStdErr', ' symmetryStdErr', ' compactnessStdErr']

# %%
# Remove less important features
X_attributes = X_attributes[most_important_attributes_list]
X_attributes_test = X_attributes_test[most_important_attributes_list]

# %%
random_forest_classifier = DecisionTreeClassifier(random_state=42)

random_forest_classifier.fit(X_attributes, Y_class)



# DT_model = DecisionTreeClassifier(random_state=42)
# DT_model.fit(X_attributes , Y_class)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = random_forest_classifier.predict(X_attributes_test)


y_true_np = Y_class_test.values
y_pred_np = np.array(y_pred)



f1 = f1_score(Y_class_test, y_pred_np, average='weighted')
print(f"F1 Score: {f1}")


# classification_report = classification_report(Y_class_test, y_pred)
# print(classification_report)
# Out:
# F1 Score: 0.748898678414097

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_attributes, Y_class)
y_pred = knn.predict(X_attributes_test)


f1 = f1_score(Y_class_test, y_pred_np, average='weighted')
print(f"F1 Score: {f1}")

print(f'Accuracy: {accuracy_score(Y_class_test, y_pred)}')
# Out:
# F1 Score: 0.748898678414097
# Accuracy: 0.6443661971830986

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.9651162790697675
